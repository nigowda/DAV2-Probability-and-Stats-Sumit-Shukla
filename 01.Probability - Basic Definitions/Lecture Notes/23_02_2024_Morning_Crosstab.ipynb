# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/Probability PPTs/Probability Basic Definations/Sachin_ODI.csv")
df.head()
# Out:
#    runs  NotOut mins  bf  fours  sixes      sr  Inns           Opp    Ground  \
# 0    13       0   30  15      3      0   86.66     1   New Zealand    Napier
# 1    37       0   75  51      3      1   72.54     2  South Africa  Hamilton
# 2    47       0   65  40      7      0  117.50     2     Australia   Dunedin
# 3    48       0   37  30      9      1  160.00     2    Bangladesh   Sharjah
# 4     4       0   13   9      1      0   44.44     2      Pakistan   Sharjah
#
#          Date        Winner    Won  century
# 0  1995-02-16   New Zealand  False    False
# 1  1995-02-18  South Africa  False    False
# 2  1995-02-22         India   True    False
# 3  1995-04-05         India   True    False
# 4  1995-04-07      Pakistan  False    False

# %% [markdown]
# If we randomly select a match, what's the prob that India will win?

# %%
df[df['Won']==True].shape[0]
# Out:
# 184

# %%
df.shape[0]
# Out:
# 360

# %%
df[df['Won']==True].shape[0]/df.shape[0]
# Out:
# 0.5111111111111111

# %% [markdown]
# If we randomly select a match, what's the prob that sachin will hit a century

# %%
df[df['century']==True].shape[0]/df.shape[0]
# Out:
# 0.12777777777777777

# %% [markdown]
# What's the prob of sachin scoring a century and india winning?

# %%
df[(df['century']==True) & (df['Won']==True)].shape[0]/df.shape[0]
# Out:
# 0.08333333333333333

# %% [markdown]
# If we want to evaluate the prob of two events together we may use cross tab

# %%
pd.crosstab(df['century'], df['Won'])
# Out:
# Won      False  True
# century
# False      160    154
# True        16     30

# %%
pd.crosstab(df['century'], df['Won'], margins = True)
# Out:
# Won      False  True  All
# century
# False      160   154  314
# True        16    30   46
# All        176   184  360

# %%
pd.crosstab(df['century'], df['Won'], margins = True, normalize = True)
# Out:
# Won         False      True       All
# century
# False    0.444444  0.427778  0.872222
# True     0.044444  0.083333  0.127778
# All      0.488889  0.511111  1.000000
